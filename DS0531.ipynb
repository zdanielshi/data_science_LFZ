# %% [markdown]
# <a href="https://colab.research.google.com/github/zdanielshi/personal_projects/blob/main/DS0531.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import requests

# %% [markdown]
# # NASA Example

# %% [markdown]
# NASA API key: FtSgRbxAYiBUmzRG4TqKmCoMyf3ryugklzUaYKZ4

# %%
response = requests.get('https://api.nasa.gov/techport/api/specification?api_key=FtSgRbxAYiBUmzRG4TqKmCoMyf3ryugklzUaYKZ4')

# %%
response
# Out:
# <Response [200]>

# %%
json_obj = response.json()

# %%
json_obj.keys()
# Out:
# dict_keys(['openapi', 'info', 'servers', 'paths', 'components'])

# %%
response_b = requests.get('https://api.nasa.gov/techport/api/projects?updatedSince=2016-01-01&api_key=FtSgRbxAYiBUmzRG4TqKmCoMyf3ryugklzUaYKZ4')

# %%
response_b
# Out:
# <Response [200]>

# %%
projects = response_b.json()

# %%
projects

# %%
response_c = requests.get('https://api.nasa.gov/techport/api/projects/105685?api_key=FtSgRbxAYiBUmzRG4TqKmCoMyf3ryugklzUaYKZ4')

# %%
project_105685 = response_c.json()

# %%
df = pd.DataFrame.from_dict(project_105685)

# %%
df = df.T

# %%
df['website']
# Out:
# project    https://etd.gsfc.nasa.gov/
# Name: website, dtype: object

# %% [markdown]
# # IMDB Exercise

# %% [markdown]
# API Key (v3 auth)
#
# 0629ce09539e8a9385337e99c10d9c01
#
# Example API Request
#
# https://api.themoviedb.org/3/movie/550?api_key=0629ce09539e8a9385337e99c10d9c01
#
# API Read Access Token (v4 auth)
#
# eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNjI5Y2UwOTUzOWU4YTkzODUzMzdlOTljMTBkOWMwMSIsInN1YiI6IjYyOTZjM2RkMWU5MjI1MDA2NDFhMDRhZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Y13CgGZ6_JwGKBa6QiApmvSWxrEvCy8KkcdVPwOhA3Y

# %%
response_sw = requests.get('https://api.themoviedb.org/3/search/movie?api_key=0629ce09539e8a9385337e99c10d9c01&language=en-US&page=1&query=Star+wars')
response_sw
# Out:
# <Response [200]>

# %%
sw_movies_data = response_sw.json()

# %%
results = sw_movies_data['results']
df_results = pd.DataFrame(results)

# %%
df_results.head()
# Out:
#    adult                     backdrop_path             genre_ids      id  \
# 0  False  /zqkmTXzjkAgXmEWLRsY4UpTWCeo.jpg         [12, 28, 878]      11
# 1  False  /f53Jujiap580mgfefID0T0g2e17.jpg  [10751, 16, 878, 35]  857702
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg     [12, 28, 878, 14]  140607
# 3  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg         [12, 28, 878]  181808
# 4  False   /SPkEiZGxq5aHWQ2Zw7AITwSEo2.jpg         [12, 28, 878]  181812
#
#   original_language                    original_title  \
# 0                en                         Star Wars
# 1                en   LEGO Star Wars Terrifying Tales
# 2                en      Star Wars: The Force Awakens
# 3                en          Star Wars: The Last Jedi
# 4                en  Star Wars: The Rise of Skywalker
#
#                                             overview  popularity  \
# 0  Princess Leia is captured and held hostage by ...      98.880
# 1  Poe Dameron and BB-8 must face the greedy crim...      85.122
# ...

# %%
df_results_popular_sort = df_results.sort_values(by='popularity', ascending=False)
df_results_popular_sort.head()
# Out:
#    adult                     backdrop_path             genre_ids      id  \
# 0  False  /zqkmTXzjkAgXmEWLRsY4UpTWCeo.jpg         [12, 28, 878]      11
# 2  False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg     [12, 28, 878, 14]  140607
# 1  False  /f53Jujiap580mgfefID0T0g2e17.jpg  [10751, 16, 878, 35]  857702
# 4  False   /SPkEiZGxq5aHWQ2Zw7AITwSEo2.jpg         [12, 28, 878]  181812
# 3  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg         [12, 28, 878]  181808
#
#   original_language                    original_title  \
# 0                en                         Star Wars
# 2                en      Star Wars: The Force Awakens
# 1                en   LEGO Star Wars Terrifying Tales
# 4                en  Star Wars: The Rise of Skywalker
# 3                en          Star Wars: The Last Jedi
#
#                                             overview  popularity  \
# 0  Princess Leia is captured and held hostage by ...      98.880
# 2  Thirty years after defeating the Galactic Empi...      89.155
# ...

# %% [markdown]
# Best rated movie = Star Wars. Genre IDs = 12, 28, 878

# %%
# response_sw_genre = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=0629ce09539e8a9385337e99c10d9c01&language=en-US&sort_by=popularity.desc&include_adult=false&with_genres=[12,28,878]')
response_sw_genre = requests.get('https://api.themoviedb.org/3/movie/11/similar?api_key=0629ce09539e8a9385337e99c10d9c01&language=en-US')

# %%
response_sw_genre
# Out:
# <Response [200]>

# %%
sw_genre_films = response_sw_genre.json()
sw_genre_films = sw_genre_films['results']
df_sw_genre = pd.DataFrame(sw_genre_films)

# %%
df_sw_genre.head()
# Out:
#    adult                     backdrop_path                 genre_ids    id  \
# 0  False  /g0pF9jXhPqm6TN3AAMWn0YeYayi.jpg             [28, 16, 878]  9323
# 1  False  /fHDAbqV14BX13K21e2bO9wX9dB5.jpg       [12, 28, 35, 10749]  9326
# 2  False  /mVuH9hNGnxF9bbhlh1Tr9FuG3Uc.jpg  [12, 16, 10751, 14, 878]  9016
# 3  False  /n7p6UTAZtkeoHkwCO42BEQaMFJY.jpg             [18, 878, 12]   644
# 4  False  /jMBpJFRtrtIXymer93XLavPwI3P.jpg             [28, 53, 878]   679
#
#                           title original_language  \
# 0            Ghost in the Shell                ja
# 1           Romancing the Stone                en
# 2               Treasure Planet                en
# 3  A.I. Artificial Intelligence                en
# 4                        Aliens                en
#
#                  original_title  \
# 0            GHOST IN THE SHELL
# 1           Romancing the Stone
# 2               Treasure Planet
# 3  A.I. Artificial Intelligence
# 4                        Aliens
#
# ...

# %%
df_sw_genre['vote_average'].mean()
# Out:
# 7.0825499999999995

# %% [markdown]
# Favorite movie is 'Crazy Rich Asians'

# %%
fav_film_request = requests.get('https://api.themoviedb.org/3/search/movie?api_key=0629ce09539e8a9385337e99c10d9c01&language=en-US&page=1&include_adult=false&query=Crazy+Rich+Asians')

# %%
fav_film = fav_film_request.json()
fav_film_results = fav_film['results']
df_fav_film = pd.DataFrame(fav_film_results)
df_fav_film
# Out:
#    adult                     backdrop_path        genre_ids      id  \
# 0  False  /qQz3fnBbLwMV4iveMFUApXC5h7G.jpg  [35, 18, 10749]  455207
# 1  False                              None  [10749, 35, 18]  972659
#
#   original_language                         original_title  \
# 0                en                      Crazy Rich Asians
# 1                en  Untitled 'Crazy Rich Asians' Spin-Off
#
#                                             overview  popularity  \
# 0  An American-born Chinese economics professor a...       22.19
# 1  A spin-off to the 2018 film 'Crazy Rich Asians...        0.60
#
#                         poster_path release_date  \
# 0  /1XxL4LJ5WHdrcYcihEZUCgNCpAW.jpg   2018-08-15
# 1                              None
#
#                                    title  video  vote_average  vote_count
# 0                      Crazy Rich Asians  False           7.1        3012
# 1  Untitled 'Crazy Rich Asians' Spin-Off  False           0.0           0

# %% [markdown]
# Crazy Rich Asians ID = 455207

# %%
cra_similar_request = requests.get('https://api.themoviedb.org/3/movie/11/similar?api_key=0629ce09539e8a9385337e99c10d9c01&language=en-US')
cra_similar_request
# Out:
# <Response [200]>

# %%
cra_sim_json = cra_similar_request.json()
cra_sim_results = cra_sim_json['results']
df_cra_sim = pd.DataFrame(cra_sim_results)

df_cra_sim
# Out:
#     adult                     backdrop_path                 genre_ids    id  \
# 0   False  /g0pF9jXhPqm6TN3AAMWn0YeYayi.jpg             [28, 16, 878]  9323
# 1   False  /fHDAbqV14BX13K21e2bO9wX9dB5.jpg       [12, 28, 35, 10749]  9326
# 2   False  /mVuH9hNGnxF9bbhlh1Tr9FuG3Uc.jpg  [12, 16, 10751, 14, 878]  9016
# 3   False  /n7p6UTAZtkeoHkwCO42BEQaMFJY.jpg             [18, 878, 12]   644
# 4   False  /jMBpJFRtrtIXymer93XLavPwI3P.jpg             [28, 53, 878]   679
# 5   False  /pyTDtQCn5sG8gi2zkM5ZylSNmtJ.jpg              [12, 28, 53]   681
# 6   False  /z7Jp7HAsY7MqXzPYzTjJnmOQk2r.jpg              [12, 28, 53]   699
# 7   False  /3tSCdgdUpXmkpHtAoQJgTt1LSI0.jpg             [878, 35, 80]   816
# 8   False  /8TnEls6hvTTXZZvc8nx4ShaPGlx.jpg         [12, 35, 80, 878]   817
# 9   False  /5wJ2tckpvwcxGCAgZiccodwEJpf.jpg             [28, 878, 12]   841
# 10  False  /3E5pvJLNEz5WmYWl6GfFW8hEVV3.jpg           [18, 36, 10752]   857
# ...
